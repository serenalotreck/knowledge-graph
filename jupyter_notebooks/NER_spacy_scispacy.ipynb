# %% [markdown]
# ## Pre-example: general domain text

# %%
import spacy
from spacy import displacy

from collections import defaultdict
import numpy as np 
import pandas as pd

# %%
obama_text = 'Barack Hussein Obama II is an American politician and attorney who served as the 44th president of the United States from 2009 to 2017. A member of the Democratic Party, Obama was the first African American president of the United States. He previously served as a U.S. senator from Illinois from 2005 to 2008 and an Illinois state senator from 1997 to 2004. '

# %%
nlp = spacy.load("en_core_web_md")

# %%
doc_obama = nlp(obama_text)

# %%
displacy.render(doc_obama, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Barack Hussein Obama II
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is an
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  politician and attorney who served as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     44th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  president of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . A member of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Democratic Party
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Obama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     African American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  president of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . He previously served as a
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  senator from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Illinois
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2005
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and an
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Illinois
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  state senator
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     from 1997 to 2004
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div></span>

# %% [markdown]
# # NER with pre-trained models
# In this notebook:
# 1. NER with spaCy medium english model
# 2. NER with scispaCy medium ensligh science model
# 3. Alignment of extracted entities

# %% [markdown]
# ## 1. spaCy

# %% [markdown]
# ### Read in abstracts as a string:

# %%
with open('/home/serenalotreck/projects/knowledge-graph/data/abstract-jasmonicac-set.txt') as f:
    text = " ".join([x.strip() for x in f])

print(text[:1000])
# Out:
# 1. Plant J. 2017 Aug;91(3):491-504. doi: 10.1111/tpj.13585. Epub 2017 Jun 9.  Regulation of the turnover of ACC synthases by phytohormones and heterodimerization in Arabidopsis.  Lee HY(1), Chen YC(1), Kieber JJ(2), Yoon GM(1).  Author information: (1)Department of Botany and Plant Pathology, Purdue University, West Lafayette, IN, 47907, USA. (2)Department of Biology, University of North Carolina, Chapel Hill, NC, 27599, USA.  Ethylene influences many aspects of plant growth and development. The biosynthesis of ethylene is highly regulated by a variety of internal and external cues. A key target of this regulation is 1-aminocyclopropane-1-carboxylic acid (ACC) synthases (ACS), generally the rate-limiting step in ethylene biosynthesis, which is regulated both transcriptionally and post-transcriptionally. Prior studies have demonstrated that cytokinin and brassinosteroid (BR) act as regulatory inputs to elevate ethylene biosynthesis by increasing the stability of ACS proteins. Here, we d

# %% [markdown]
# ### Load the spaCy model:

# %%
nlp = spacy.load("en_core_web_md")

# %% [markdown]
# ### Create doc object:

# %%
doc = nlp(text)

# %% [markdown]
# ### Check out the extracted entities:

# %% [markdown]
# Get a look at the entities using displaCy:

# %%
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . Plant J.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Aug;91(3):491-
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     504
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . doi:
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10.1111
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# /tpj.13585. Epub
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Jun 9.  Regulation of the turnover of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  synthases by phytohormones and heterodimerization in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arabidopsis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lee HY(1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ),
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chen YC(1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ),
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kieber JJ(2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ),
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yoon GM(1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ).  Author information: (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1)Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of Botany and Plant Pathology,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Purdue University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     West Lafayette
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , IN,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     47907
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2)Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of Biology,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     University of North Carolina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chapel Hill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27599
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .  Ethylene influences many aspects of plant growth and development. The biosynthesis of ethylene is highly regulated by a variety of internal and external cues. A key target of this regulation is
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1-aminocyclopropane-1-carboxylic
#     <s

# %% [markdown]
# What types were identified, and how many of each?

# %%
types = defaultdict(int)
for ent in doc.ents:
    types[ent.label_] += 1
    
print(types)
# Out:
# defaultdict(<class 'int'>, {'CARDINAL': 164, 'ORG': 304, 'PERSON': 154, 'GPE': 123, 'DATE': 56, 'WORK_OF_ART': 7, 'NORP': 3, 'FAC': 10, 'TIME': 1, 'LOC': 3, 'QUANTITY': 8, 'PRODUCT': 20, 'EVENT': 3, 'LAW': 3, 'MONEY': 2, 'PERCENT': 2, 'ORDINAL': 2, 'LANGUAGE': 1})

# %% [markdown]
# Some of these types make no sense for our application. For example, `WORK_OF_ART`. What spans were identified as this type? What spans were identified under each type?

# %%
type_value = defaultdict(set)
for ent in doc.ents:
    type_value[ent.label_].add(ent.text)
    
print(type_value['WORK_OF_ART'])
# Out:
# {'Safitri FA(1', 'Arabidopsis', 'MeJA', 'The Authors', 'Rodríguez D', 'PMC6501071'}

# %%
print(type_value['FAC']) # FAC is facility
# Out:
# {'Plant', 'Conti G(3)(4', 'jasmonate', 'Gymnasium Place', 'López-Climent M', 'CpMYC2', 'Kitayama M', 'LC-Orbitrap-MS', 'the COI1-JAZ-DELLA-PIF', 'Gómez-Cadenas A'}

# %%
print(type_value['LANGUAGE'])
# Out:
# {'PMC3358897'}

# %%
print(type_value['LAW'])
# Out:
# {'Aug;4(8):750-1', 'AtMYC2-2', 'TMV-Cg'}

# %% [markdown]
# What about entities that might make sense, like `PERSON`?

# %%
print(type_value['PERSON'], f'\nNumber of PERSON entities: {len(type_value["PERSON"])}')
# Out:
# {'Wang JR(5)(3', 'Bax', 'Dong L(1', 'Thomashow MF', 'Li N(1)(2', 'Centro Hispano-Luso de Investigaciones Agrarias', 'Deng M(3', 'Mun BG(1', 'Seebold K', 'Hoehenwarter W', 'Wei ZZ(3', 'Weckwerth W.  ', 'Cutler AJ', 'Chen L(2', 'Abid K(1', 'PMC2504347', 'Hou', 'Jiménez JA', 'Abid', 'Arabidopsis', 'Lee SK(2', 'Kasr El-Aini Street', 'Luo D(1', 'Jiang YF(3', 'Zong LJ(3', 'gibberellic acid', 'Lantz AT(2', 'Romeis T(3', 'Wang Y(3', 'Li Q,', 'Chen YC(1', 'Lu', 'Li', 'Yang N(2', 'Kachroo P.  ', 'Saeed UH(1', 'Li J', 'Zhang W(1', 'Pellny TK', 'Childs KL(5', 'Wu J(3', 'brassinosteroids', 'P. sojae', 'Chung IK(4', 'Wang', 'Isoprene', 'Xu BJ(3', 'Hedden P, Driscoll S', 'PMC7076656', 'Xu P(1', 'Mei CS', 'Brachypodium distachyon', 'Mizuno T.  ', 'Reyes D', 'Zhang S(1', 'Guo ZR(3', 'Rodriguez', 'GLABRA1', 'Biosci Biotechnol Biochem.', 'Hurlingham', 'Yu K', 'Hause B(2', 'Giavalisco', 'Zavallo', 'Nicotiana tabacum', 'Hou X(1', 'Wang X(1', 'Facultad de Biología', 'Chen R(1', 'Yang Y', 'Lee CM', 'Nicotiana tabaccum', 'gl1', 'Lan XJ(3', 'Asurmendi', 'Kiddle G', 'Wu W', 'Jasmonate', 'bbb.130559', 'Wang L(1', 'Qi', 'Abdul Wali Khan University', 'Zhang Y(1', 'jasmonic acid', 'Hussain A(1)(3)', 'Povero G', 'Liu S(1', 'Perata P.  ', 'Chen Q(3', 'Chen GY(5)(3', 'Zhang YZ(3', 'Wiszniewski A(1', 'Abrams SR', 'Meng Y(1', 'Tong XH', 'Nicolás C.  ', 'GL1', 'Wei YM(3', 'Meng', 'Kachroo A', 'Pharmacognosy', 'Sharkey TD(6)(3)(4', 'Nicolás G', 'Manacorda CA(7', 'New Phytol', 'Zheng YL(6', 'Schaller GE(1', 'Deng XW', 'DELLA', 'Anthocyanins', 'PMC3203439 PMID', 'monoterpene', 'Zhang', 'Zeng LJ', 'Weise SE(3', 'Sanchez LM(2', 'Jiang QT(3', 'Kieber JJ(2', 'Jo JH(2', 'beechnut', 'Cytokinin', 'Luo', 'Yao J', 'Yun BW(5', 'Chen X(1', 'j.1365-313X.2010.04218.x', 'Chen', 'GL3', 'sulfotransferase', 'Kim KM(6', 'Fagus', 'Huang', 'Lee HY(1', 'Novi G'}
# Number of PERSON entities: 134

# %% [markdown]
# spaCy seems to get confused by the notation used to indicate author affiliations, but otherwise does seem to pick out people fairly well. However - notice that it thinks Nicotiana benthamiana, brassinosteriods, monoterpenes, isoprene, and JA are people!

# %%
print(type_value['GPE'], f'\nNumber of GPE entities: {len(type_value["GPE"])}')
# Out:
# {'Chapel Hill', 'Yangling', 'Halle', 'Spain', 'Canada', 'Daegu', 'Salem', 'Sun TP', 'pnas.1201616109', 'Wuhan', 'Egypt', 'Buenos', 'Argentina', 'China', '0C6', 'lignan', 'Germany', 'Mardan', 'New Phytol', 'Lexington', 'Saskatoon', 'Navarre D', 'NH 03755', 'Yoon GM(1', 'Pakistan', 'West Lafayette', 'Sichuan', 'Ottawa', 'Pisa', 'Hancock RD', 'Korea', 'UK', 'plants9060785', 'NC', 'USA', 'Milwaukee WI', 'Cairo', 'Kentucky', 'gl1 plants', 'Cheng Q(1', 'East Lansing', 'Kunming 650224', 'Aires', 'Kong L(3', 'Salamanca', 'Chengdu', 'Basel', 'Italy', 'Berlin', 'Cellular', 'Shanghai 200032', 'Hanover', '0W9'}
# Number of GPE entities: 53

# %%
# Unclear why I'm getting different numbers for some types here vs when I made a dictionary that counted

# %% [markdown]
# ## 2. scispaCy

# %% [markdown]
# ### Load the model:

# %%
nlp_sci = spacy.load("en_core_sci_md")

# %% [markdown]
# ### Create doc object:

# %%
doc_sci = nlp_sci(text)

# %% [markdown]
# ### Check out the extracted entities:

# %%
displacy.render(doc_sci, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">1.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  J. 2017
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aug;91(3):491
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# -504. doi: 10.1111/tpj.13585. Epub 2017 Jun 9.  Regulation of the
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     turnover
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     synthases
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  by
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     phytohormones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     heterodimerization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arabidopsis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .  Lee HY(1), Chen
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     YC(1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ), Kieber
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JJ(2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ), Yoon
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GM(1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ).  Author information:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     (1)Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Botany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Plant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
#  Pathology,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Purdue University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     West Lafayette
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     IN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# , 47907,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# . (2)Department of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Biology
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     University of North Carolina
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chapel Hill
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# , 27599,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ENTITY</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-h

# %% [markdown]
# What types does this model identify?

# %%
'label_bin'sci_types = defaultdict(set)
for ent in doc_sci.ents:
    sci_types[ent.label_].add(ent.text)
    
print(sci_types.keys())
# Out:
# dict_keys(['ENTITY'])

# %%
print(len(sci_types['ENTITY']))
# Out:
# 1196

# %% [markdown]
# #### The core model does not have entity types!
# It merely identifies entities. According to the example in [this blog post](https://towardsdatascience.com/using-scispacy-for-named-entity-recognition-785389e7918d), the core model identifies more entities than the NER model, which only identifies the biological entities that it has types for. Let's check it out!<br>
#
# Types included in the 4 NER models:
# 1. en_ner_craft_md: types are \[GGP, SO, TAXON, CHEBI, GO, CL\].
# 2. en_ner_jnlpba_md: types are \[DNA, CELL_TYPE, CELL_LINE, RNA, PROTEIN\]
# 3. en_ner_bc5cdr_md: types are \[DISEASE, CHEMICAL\]
# 4. en_ner_bionlp13cg_md: types are \[AMINO_ACID, ANATOMICAL_SYSTEM, CANCER, CELL, CELLULAR_COMPONENT, DEVELOPING_ANATOMICAL_STRUCTURE, GENE_OR_GENE_PRODUCT, IMMATERIAL_ANATOMICAL_ENTITY, MULTI-TISSUE_STRUCTURE, ORGAN, ORGANISM, ORGANISM_SUBDIVISION, ORGANISM_SUBSTANCE, PATHOLOGICAL_FORMATION, SIMPLE_CHEMICAL, TISSUE\]
#
# In this notebook I'm going to play around with the first few models. I predict that model 2, en_ner_jnlpba_md will perform best on this data, because only one of the types isn't relevant to plant biology.

# %% [markdown]
# ### 1. en_ner_craft_md

# %%
nlp_craft = spacy.load("en_ner_craft_md")

# %%
doc_craft = nlp_craft(text)

# %%
displacy.render(doc_craft, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">1. Plant J. 2017 Aug;91(3):491-504. doi: 10.1111/tpj.13585. Epub 2017 Jun 9.  Regulation of the turnover of ACC synthases by
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     phytohormones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  and heterodimerization in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arabidopsis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TAXON</span>
# </mark>
# .  Lee HY(1), Chen YC(1), Kieber JJ(2), Yoon GM(1).  Author information: (1)Department of Botany and Plant Pathology, Purdue University, West Lafayette, IN, 47907, USA. (2)Department of Biology, University of North Carolina, Chapel Hill, NC, 27599, USA.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethylene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  influences many aspects of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     plant
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  growth and development. The biosynthesis of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ethylene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  is highly regulated by a variety of internal and external cues. A key target of this regulation is
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1-aminocyclopropane-1-carboxylic acid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  (ACC) synthases (ACS), generally the rate-limiting step in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ethylene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  biosynthesis, which is regulated both transcriptionally and post-transcriptionally. Prior studies have demonstrated that
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cytokinin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  and brassinosteroid (BR) act as regulatory inputs to elevate
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ethylene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  biosynthesis by increasing the stability of ACS
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     proteins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
# . Here, we demonstrate that several additional
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     phytohormones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  also regulate ACS
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     protein
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  turnover.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abscisic acid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     auxin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GGP</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gibberellic acid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     methyl jasmonic acid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
# , and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     salicylic acid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
#  differentially regulate the stability of ACS
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     proteins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
# , with distinct effects on various
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     isoforms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">SO</span>
# </mark>
# . In addition, we demonstrate that heterodimerization influences the stability of ACS
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     proteins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CHEBI</span>
# </mark>
# . Heterodimerization between ACS
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35e

# %% [markdown]
# ### 2. en_ner_jnlpba_md

# %%
nlp_jnlp = spacy.load("en_ner_jnlpba_md")

# %%
doc_jnlp = nlp_jnlp(text)

# %%
displacy.render(doc_jnlp, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">1. Plant J. 2017 Aug;91(3):491-504. doi: 10.1111/tpj.13585. Epub 2017 Jun 9.  Regulation of the turnover of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACC synthases
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  by phytohormones and heterodimerization in Arabidopsis.  Lee HY(1), Chen YC(1), Kieber
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JJ(2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CELL_LINE</span>
# </mark>
# ), Yoon
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GM(1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# ).  Author information: (1)Department of Botany and Plant Pathology, Purdue University, West Lafayette, IN, 47907, USA. (2)Department of Biology, University of North Carolina, Chapel Hill, NC, 27599, USA.  Ethylene influences many aspects of plant growth and development. The biosynthesis of ethylene is highly regulated by a variety of internal and external cues. A key target of this regulation is 1-aminocyclopropane-1-carboxylic acid (ACC) synthases (ACS), generally the rate-limiting step in ethylene biosynthesis, which is regulated both transcriptionally and post-transcriptionally. Prior studies have demonstrated that cytokinin and brassinosteroid (BR) act as regulatory inputs to elevate ethylene biosynthesis by increasing the stability of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACS proteins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# . Here, we demonstrate that several additional phytohormones also regulate ACS protein turnover. Abscisic acid, auxin, gibberellic acid, methyl jasmonic acid, and salicylic acid differentially regulate the stability of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACS proteins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# , with distinct effects on various isoforms. In addition, we demonstrate that heterodimerization influences the stability of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACS proteins
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# . Heterodimerization between
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACS isoforms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  from distinct subclades results in increased stability of the shorter-lived partner. Together, our study provides a comprehensive understanding of the roles of various phytohormones on ACS protein stability, which brings new insights into crosstalk between ethylene and other phytohormones, and a novel regulatory mechanism that controls ACS protein stability through a heterodimerization of
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ACS isoforms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# .  © 2017 The Authors The Plant Journal © 2017 John Wiley &amp; Sons Ltd.  DOI: 10.1111/tpj.13585 PMID: 28440947 [Indexed for MEDLINE]   2. Plant Cell. 2015 Mar;27(3):591-606. doi: 10.1105/tpc.15.00024. Epub 2015 Mar 3.  The
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     calcium-dependent protein kinase CPK28
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  regulates development by inducing growth phase-specific, spatially restricted alterations in jasmonic acid levels independent of defense responses in Arabidopsis.  Matschi S(1), Hake K(1),
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Herde M(1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# ),
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hause B(2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
# ), Romeis T(3).  Author information: (1)Department of Plant Biochemistry, Dahlem Centre of Plant Sciences, Institute for Biology, Freie Universität Berlin, 14195 Berlin, Germany. (2)Department of Cell and Metabolic Biology, Leibniz Institute of Plant Biochemistry, 06120 Halle (Saale), Germany. (3)Department of Plant Biochemistry, Dahlem Centre of Plant Sciences, Institute for Biology, Freie Universität Berlin, 14195 Berlin, Germany tina.romeis@fu-berlin.de.  Phytohormones play an important role in development and stress adaptations in plants, and several interacting hormonal pathways have been suggested to accomplish fine-tuning of stress responses at the expense of growth. This work describes the role played by the CALCIUM-DEPENDENT PROTEIN KINASE
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CPK28
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROTEIN</span>
# </mark>
#  in balancing phytohormone-mediated development in Arabidopsis thaliana, specifically during generative growth. cpk28 mutants exhibit growth reduction solely as adult plants, coinciding with altered balance of the phytohormones jasmonic acid (JA) and gibberellic acid (GA).
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JA-dependent gene
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DNA</span>
# </mark>
#  expression and the levels of several JA metabolites were elevated in a growth phase-dependent manner in cpk28, and accumulation of JA metabolites was confined locally to the central rosette tissue. No elevated resistance toward herbivores or necrotrophic pathogens was detected for cpk28 plants, either on the whole-plant level or specifically within the tissue displaying elevated JA levels.

# %% [markdown]
# After manually inspecting the NER outputs of these three scispaCy models, it appears that the full pipeline model, with only type ENTITY, actually has the highest recall on the entities we want to extract from this text. However, this is a qualitative observation. In order to get a quantitative evaluation, we need to complete our Gold Standard by deciding what entities we do want to extract.

# %% [markdown]
# ## 3. Visualization of model comparison

# %% [markdown]
# While skimming the displaCy renderings gives an idea of which models extracted more entities, let's look more in-depth at the differences between models. First, we'll make a table using spaCy's IOB scheme. We'll make a dataframe where each row is one token from the text. The subsequent columns will give us the IOB value for each token in the various models. <br>
#
# If a token recieves I, that means it's inside an entity span. If it recieves a B, it's the beginning of an entity span, and if it recieves an O, it's outside an entity span (not an entity).

# %% [markdown]
# First, let's get the tokens and their annotations from each doc object.

# %%
doc_iob = [(t.text, t.ent_iob_, t.ent_type_) for t in doc]
doc_sci_iob = [(t.text, t.ent_iob_, t.ent_type_) for t in doc_sci]
doc_craft_iob = [(t.text, t.ent_iob_, t.ent_type_) for t in doc_craft]
doc_jnlp_iob = [(t.text, t.ent_iob_, t.ent_type_) for t in doc_jnlp]

# %%
print(len(doc_iob), len(doc_sci_iob), len(doc_craft_iob), len(doc_jnlp_iob))
# Out:
# 8389 7960 7960 7960

# %% [markdown]
# It looks like spaCy and scispaCy split tokens differently. This is most likely because scispaCy uses a custom tokenizer, but I'll have to check.

# %% [markdown]
# Since they split tokens differently, it doesn't necessarily make sense to compare the spaCy and scispaCy model entities, so I'll just compare the entities extracted from the scispaCy models.

# %% [markdown]
# Make a tuple for each token, containing its text, iob value and type:

# %%
sci_iob_df = pd.DataFrame(doc_sci_iob, columns=['text', 'sci_ent_iob', 'sci_ent_type'])
craft_iob_df = pd.DataFrame(doc_craft_iob, columns=['text', 'craft_ent_iob', 'craft_ent_type'])
jnlp_iob_df = pd.DataFrame(doc_jnlp_iob, columns=['text', 'jnlp_ent_iob', 'jnlp_ent_type'])

# %% [markdown]
# Check that the tokens are indeed identical:

# %%
sci_iob_df['text'].equals(craft_iob_df['text'])
# Out:
# True

# %%
craft_iob_df['text'].equals(jnlp_iob_df['text'])
# Out:
# True

# %% [markdown]
# Add on the columns for iob and type from each model. For some reason, using pd.merge on the 'text' column produces many many dupliocate rows. Since I've confirmed that all three text columns are equivalent, I'm going to tack on the relevant columns.

# %%
all_iob_df = sci_iob_df
all_iob_df['craft_ent_iob'] = craft_iob_df['craft_ent_iob']
all_iob_df['craft_ent_type'] = craft_iob_df['craft_ent_type']
all_iob_df['jnlp_ent_iob'] = jnlp_iob_df['jnlp_ent_iob']
all_iob_df['jnlp_ent_type'] = jnlp_iob_df['jnlp_ent_type']

# %%
all_iob_df.head()
# Out:
#     text sci_ent_iob sci_ent_type craft_ent_iob craft_ent_type jnlp_ent_iob  \
# 0      1           O                          O                           O
# 1      .           O                          O                           O
# 2  Plant           B       ENTITY             O                           O
# 3     J.           O                          O                           O
# 4   2017           O                          O                           O
#
#   jnlp_ent_type
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# Now, let's drop all the rows where none of the models label the text as an entity, so we can better compare.

# %%
index_sci = all_iob_df[all_iob_df['sci_ent_iob']=='O'].index.tolist()
index_craft = all_iob_df[all_iob_df['craft_ent_iob']=='O'].index.tolist()
index_jnlp = all_iob_df[all_iob_df['jnlp_ent_iob']=='O'].index.tolist()

# %%
index_drop = [i for i in index_sci if (i in index_craft and i in index_jnlp)]

# %%
# Spot check the indices
to_drop = all_iob_df.iloc[index_drop]
to_drop
# Out:
#           text sci_ent_iob sci_ent_type craft_ent_iob craft_ent_type  \
# 0            1           O                          O
# 1            .           O                          O
# 3           J.           O                          O
# 4         2017           O                          O
# 6            -           O                          O
# ...        ...         ...          ...           ...            ...
# 7955        no           O                          O
# 7956  conflict           O                          O
# 7957        of           O                          O
# 7958  interest           O                          O
# 7959         .           O                          O
#
#      jnlp_ent_iob jnlp_ent_type
# 0               O
# 1               O
# 3               O
# 4               O
# 6               O
# ...           ...           ...
# 7955            O
# 7956            O
# 7957            O
# 7958            O
# 7959            O
#
# [4671 rows x 7 columns]

# %%
# Drop rows where no model identified the token as an entityb
entities_iob = all_iob_df.drop(index_drop)
entities_iob
# Out:
#                text sci_ent_iob sci_ent_type craft_ent_iob craft_ent_type  \
# 2             Plant           B       ENTITY             O
# 5     Aug;91(3):491           B       ENTITY             O
# 22         turnover           B       ENTITY             O
# 24              ACC           B       ENTITY             O
# 25        synthases           B       ENTITY             O
# ...             ...         ...          ...           ...            ...
# 7938           PMID           B       ENTITY             O
# 7942        Indexed           B       ENTITY             O
# 7944        MEDLINE           B       ENTITY             O
# 7950      statement           B       ENTITY             O
# 7953        authors           B       ENTITY             O
#
#      jnlp_ent_iob jnlp_ent_type
# 2               O
# 5               O
# 22              O
# 24              B       PROTEIN
# 25              I       PROTEIN
# ...           ...           ...
# 7938            O
# 7942            O
# 7944            O
# 7950            O
# 7953            O
#
# [3289 rows x 7 columns]

# %% [markdown]
# Now let's break these down further. <br>
#
# 1. The sci model is clearly overzealous - what entities did it identify that the other models didn't?
# 2. The sci model is also mode aggressive about breaking spans up into multiple entities - are any of the entities more than one token long? (Are any of the IOB values == I?)
# 3. What entities do CRAFT and JNLPBA models have in common? What do they not have in common?
# 4. Are there any entities NOT identified by the sci model that are identified by others?

# %% [markdown]
# #### 1. Overzealous sci model
# Want to look at rows where the iob is O for the other two models

# %%
index_ents = entities_iob[entities_iob['craft_ent_iob']=='O'].index.tolist()

# %% [markdown]
# Something that may also be interesting is, what are the things that weren't identified as entites by any model? Do we care about them or want them to be extracted as entities in the future?
